# %% [markdown]
# <a href="https://colab.research.google.com/github/Yoikitenkai788/Pemrograman-Dasar/blob/main/Pertemuan_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. dokumentasi resmi phyton menyediakan tabel yang merangkum urutan prioritas operator dari yang paling tinggi hingga ke paling rendah, yang dimana urutannya itu untuk dalam kotak yang sama memiliki prioritas yang setara. dalam tabel tersebut, operator perkalian,pembagian(/,//),dan modulus (%) berada satu level diatas operator penjumlahan dan pengurangan(+,-).Sumber: Python 3 Language Reference — 6.17 Operator Precedence.
# kenapa ekspresi 10 +5*2 menghasilkan 20,bukan 30 karena
# pada python tidak membaca operator dari kiri dan kanan akan tetapi berdasarkan level operasi bilangan. operator * memiliki level lebih tinggi dibandingkan operator +, sehingga phyton menghitung yang 5 * 2 terlebih dahulu menjadi nilai 10, baru kemudian dengan 10 dari operator + sehingga hasil menjadi 20 bukan 30. aturan operasi ini  sama dengan aturan matematika yang dimana perkalian dan pembagian di dahulukan daripada penjumlahan dan pengurangan kecuali ada tanda kurung yang mengubah aturan tersebut.
#
# 2. perbedaan mendasar antara operator relasional dengan operator logika berdasarkan contohnya pada operator relasional >,<, ==, dll sedangkan operator logika (and,or not). berdasarkan apa yang dibandingan nilai pada operator relasional adalah berupa nilai dua objek atau data (angka,string,dll) sedangkan operator logika berupa nilai boolean true atau false atau ekspresi yang bisa dinilai kebenarannya.berdasarkan hasil operasi, pada operator relasional selalu berupa true atau false(satu perbandingan) sedangkan pada operator logika berupa menggabungkan/memodifikasi beberapa hasil boolean menjadi kesimpulan. berdasarkan fungsi pada operator relasition hasil yang diberikan berupa pernyataan dari data sedangkan operator logika berupa keputusan akhir. kesimpulannya pada operator relasation itu membuat satu pernyataan boolean dari data, sedangkan operator logika menggabungkan beberapa pernyataan boleaan menjadi satu keputusan akhir.
# contoohnya pada sistem pemesanan tiket pesawat online yang menentukan apakah penumpang boleh check in online. syaratnya waktu keberangkatan masih lebih dari satu jam lagi dan kurang dari 24 jam sebelum keberangkatan dan status tiket sudah dibatalkan.
#
# boleh_checkin = (sisa_jam_ke_keberangkatan > 1) and (sisa_jam_ke_keberangkatan < 24) and (status_tiket != "dibatalkan")
#
# disini operator relasional dipakai untuk membuat tiga pernyataan boleaan terpisah dari data numerik dan status tiket lalu operator and menggabungkan ketiganya menjadi satu keputusan tunggal: boleh check in atau tidak. tanpa kombinasi keduanya dan sistem tidak bisa menangkap kondisi tersebut.
#
# 3. kasus MITRE yang mendokumentasikan bug pada aplikasi keuangan yang menghitung return on investment (ROI) menggunakan rumus
# returnROI = currentValue - initialInvestment / initialInvestment; tanpa menggunakan tanda kurung.
# Karena operator pembagian (/) memiliki prioritas lebih tinggi daripada pengurangan (-), Python akan mengerjakan initialInvestment / initialInvestment terlebih dahulu, yang hasilnya selalu 1. Akibatnya, rumus tersebut hanya mengurangi 1 dari currentValue, bukan menghitung ROI yang sebenarnya (selisih nilai investasi dibagi biaya awal). Bug jenis ini tergolong serius karena bisa lolos dari pengujian sekilas — hasilnya tetap berupa angka yang "masuk akal", padahal secara matematis salah total.
#
# cara memperbaikinya dengan menambah tanda kurung untuk memaksakan pengurangan dikerjakan terlebih dahulu sebelum pembagian.
#
# Sumber: MITRE CWE-783: Operator Precedence Logic Error

# %%
#NAMA :AHMAD FAUZAN
#NIM  :4232501016
#24/09/2026
#memasukkan dua bilangan bulat

a = int(input("memasukkan bilangan pertama :"))
b = int(input("memasukkan bilangan kedua :"))
#penjumlahan
print(f"{a} +{b} = {a+b}")
#pengurangan
print(f"{a}-{b} = {a-b}")
#perkalian
print(f"{a}*{b} = {a*b}")
#pembagian
print(f"{a} / {b} = {a / b}")
print(f"{a} // {b} = {a//b}")
print(f"{a}%{b}= {a%b}")
# Out:
# memasukkan bilangan pertama :2
# memasukkan bilangan kedua :4
# 2 +4 = 6
# 2-4 = -2
# 2*4 = 8
# 2 / 4 = 0.5
# 2 // 4 = 0
# 2%4= 2

# %%
#AHMAD FAUZAN
#4232501016
#cek kelulusan nilai

nilai = float(input("memasukkan nilai ujian (0-100):"))

lulus = nilai >=70
print(f"nilai ini termasuk kategori lulus (>=70):{lulus}")
# Out:
# memasukkan nilai ujian (0-100):90
# nilai ini termasuk kategori lulus (>=70):True

# %%
#AHMAD FAUZAN
#4232501016
#program operator logika

umur= int(input('masukkan umur:'))
punya_sim= input ("punya sim? (true/false):"). strip() .lower()== "true"

boleh_mengemudi = (umur >= 17) and (punya_sim == True)

print(f"Boleh mengemudi : {boleh_mengemudi}")
# Out:
# masukkan umur:16
# punya sim? (true/false):true
# Boleh mengemudi : False

# %%
#Ahmad Fauzan
#4232501016
#menghitung efisiensi thermal pembangkit

energi_input = float(input("memasukkan energi input (MJ): "))
energi_output = float(input("memasukkan energi output (MJ):"))
efisiensi = (energi_output/energi_input)* 100
print(f"efisiensi termal unit pembangkit: {efisiensi:2f}%")
# Out:
# memasukkan energi input (MJ): 50
# memasukkan energi output (MJ):40
# efisiensi termal unit pembangkit: 80.000000%

# %%
#AHMAD FAUZAN
#4232501016
#memasukkan suhu boiler dan beban operasi

suhu_boiler = float(input("masukkan suhu boiler (°C):"))
beban_operasi =float(input("masukkan beban operasi (%):"))

perlu_maintenance = (suhu_boiler > 500) or (beban_operasi > 90)

print(f"unit pembangkit dengan suhu boiler {suhu_boiler}°C dan beban operasi{beban_operasi}% "
      f"berstatus 'perlu maintenance': {perlu_maintenance}.")
# Out:
# masukkan suhu boiler (°C):400
# masukkan beban operasi (%):60
# unit pembangkit dengan suhu boiler 400.0°C dan beban operasi60.0% berstatus 'perlu maintenance': False.

# %% [markdown]
# <a href="https://colab.research.google.com/github/Yoikitenkai788/Pemrograman-Dasar/blob/main/Pertemuan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#biodata saya
nama_lengkap = "Ahmad Fauzan"
nama_panggilan ="fauzan"
umur = 20
tempat_tanggal_lahir ="batam,6september2006"
asal_daerah ="batam"
jurusan ="elektro"
prodi ="TRPE"
semester =3
matakuliah ="pemerograman Dasar"
status_lulus = False

print (nama_lengkap)
print (nama_panggilan)
print (umur)
print (tempat_tanggal_lahir)
print (asal_daerah)
print (jurusan)
print (prodi)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Ahmad Fauzan
# fauzan
# 20
# batam,6september2006
# batam
# elektro
# TRPE
# 3
# pemerograman Dasar
# False

# %% [markdown]
# <a href="https://colab.research.google.com/github/Yoikitenkai788/Pemrograman-Dasar/blob/main/Latihan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Jawaban Latihan 1
tegangan_panel= (18)
arus = (6)
jenis_sel = "Monocrytalline"

print(tegangan_panel)
print(arus)
print(jenis_sel)
# Out:
# 18
# 6
# Monocrytalline

# %%
# Jawaban Latihan 2
induktor =24
arus= 23.6
status_komponen=('hidup')
berfungsi= True

print(type(induktor))
print(type(arus))
print(type(status_komponen))
print(type(berfungsi))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# Jawaban Latihan 3
Nama_unit= "PLTS Nunukan"
Jumlah_panel= 240
Tegangan_keluaran = 48.5
Sedang_beroperasi= True

print(type(Nama_unit))
print(type(Jumlah_panel))
print(type(Tegangan_keluaran))
print(type(Sedang_beroperasi))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
#Jawaban Latihan 4
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

#A
print("tegangan_ pertama:",tegangan_harian[0])
print("tegangan_ terakhir:",tegangan_harian[5])

#B
tegangan_harian.append(222.0)
print("setelah_ditambah:",tegangan_harian)

#C
print(len(tegangan_harian))
# Out:
# tegangan_ pertama: 217.5
# tegangan_ terakhir: 216.9
# setelah_ditambah: [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 222.0]
# 7

# %%
# Jawaban Latihan 5
motor_listrik ={'nama':"motor_asinkron",'daya_kw':67.9,'tegangan_V':320,'rpm':1000}
print (motor_listrik['nama'])
motor_listrik ['rpm'] = 3000
print(motor_listrik)
# Out:
# motor_asinkron
# {'nama': 'motor_asinkron', 'daya_kw': 67.9, 'tegangan_V': 320, 'rpm': 3000}

# %%
# Jawaban Latihan 6
pembangkit = [
    {"PLTGU": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"PLTS": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"PLTG": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
]

print(pembangkit [1]["PLTS"])
pembangkit [2]["status"] = "operasi"
pembangkit.append ({"PLTB": "unit-4","kapasitas_MW": 100, "status":"pemeliharaan"})
print ("\n2.Seluruh data pembangkit setelah diperbaharui:")
for unit in pembangkit:
  print (unit)
# Out:
# Unit-2
#
# 2.Seluruh data pembangkit setelah diperbaharui:
# {'PLTGU': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}
# {'PLTS': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}
# {'PLTG': 'Unit-3', 'kapasitas_MW': 80, 'status': 'operasi'}
# {'PLTB': 'unit-4', 'kapasitas_MW': 100, 'status': 'pemeliharaan'}
